# %%
with open("data.csv", 'r') as table:
    for row in table:
        print(row[0:8]) #token-pair
        print(row[33:59]) #buy
        print(row[12:19]) #Dex
        print(row[70:100])  #sell
        print(row[-20:-14]) #Dex
        print('-------------')
# Out:
# KNC/USDT
# 'buy_price_wei': 0.443025,
# UNISWAP
# e_wei': 0.050602846022302805},
#  KYBER
# -------------
# KNC/LINK
# 'buy_price_wei': 0.0584236
# UNISWAP
#  'sell_price_wei': 0.038317759
#  KYBER
# -------------
# LINK/WBT
# {'buy_price_wei': 0.000126
# 'UNISWA
# rice_wei': 2.826171476852383e-
#  KYBER
# -------------
# KNC/MKR,
# buy_price_wei': 5956056.95
# NISWAPB
# ll_price_wei': 4284182.6604700
#  KYBER
# -------------
# MKR/KNC,
# buy_price_wei': 1.40097598
# NISWAPB
# ell_price_wei': 1.392582655475
# NISWAP
# -------------
# USDC/BNT
# 'buy_price_wei': 0.2123499
# UNISWAP
#  'sell_price_wei': 0.167881109
#  KYBER
# -------------
# TUSD/DAI
# 'buy_price_wei': 0.5723710
# UNISWAP
# 'sell_price_wei': 0.2974829460
#  KYBER
# -------------
# LINK/KNC
# 'buy_price_wei': 3.0038666
# UNISWAP
# 'sell_price_wei': 0.3735628753
#  KYBER
# -------------
# LINK/BNT
# 'buy_price_wei': 3.7105817
# UNISWAP
# 'sell_price_wei': 2.4453505780
#  KYBER
# -------------
# DAI/BNT,
# ...
